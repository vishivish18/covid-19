# %%
import pandas as pd
import requests
import io
import datetime
import pymongo
import numpy as np

# %%
myclient = pymongo.MongoClient("mongodb+srv://jarvis:iJeX.3yhgazU29#@covid-19-f8hds.mongodb.net/test")
database = myclient["covid-19"]
india_collection = database["india"]

# %%
r = requests.get('https://api.covid19india.org/data.json')
data = r.json()

# %%
for state in data['statewise']:
    a = 10
    #print(state['state'])

# %%
STATE_CODES = {
  "AP": 'Andhra Pradesh',
  "AR": 'Arunachal Pradesh',
  "AS": 'Assam',
  "BR": 'Bihar',
  "CT": 'Chhattisgarh',
  "GA": 'Goa',
  "GJ": 'Gujarat',
  "HR": 'Haryana',
  "HP": 'Himachal Pradesh',
  "JH": 'Jharkhand',
  "KA": 'Karnataka',
  "KL": 'Kerala',
  "MP": 'Madhya Pradesh',
  "MH": 'Maharashtra',
  "MN": 'Manipur',
  "ML": 'Meghalaya',
  "MZ": 'Mizoram',
  "NL": 'Nagaland',
  "OR": 'Odisha',
  "PB": 'Punjab',
  "RJ": 'Rajasthan',
  "SK": 'Sikkim',
  "TN": 'Tamil Nadu',
  "TG": 'Telangana',
  "TR": 'Tripura',
  "UT": 'Uttarakhand',
  "UP": 'Uttar Pradesh',
  "WB": 'West Bengal',
  "AN": 'Andaman and Nicobar Islands',
  "CH": 'Chandigarh',
  "DN": 'Dadra and Nagar Haveli',
  "DD": 'Daman and Diu',
  "DL": 'Delhi',
  "JK": 'Jammu and Kashmir',
  "LA": 'Ladakh',
  "LD": 'Lakshadweep',
  "PY": 'Puducherry',
}

# %%
r = requests.get('https://api.covid19india.org/states_daily.json')
response = r.json()
total_confirmed = 0
total_deaths = 0
total_recovered = 0
total_active = 0
for idx, data in enumerate(response['states_daily']):
    overalldate = datetime.datetime.strptime(data['date'],'%d-%b-%y')
    day = str(overalldate.day)
    month = str(overalldate.month)
    year = str(overalldate.year)
    counter = 0
    if len(day) < 2:
        day = '0'+str(day)
    if len(month) < 2:
        month = '0'+str(month)
    valid_date = month+'-'+day+'-'+year
    if counter <= 2:
        if data['status'] =='Confirmed':
            confirmed = int(data['dl'])
        if data['status'] =='Recovered':
            recovered = int(data['dl'])
        if data['status'] =='Deceased':
            deaths = int(data['dl'])
            active = confirmed - (recovered + deaths)
            print("IN DELHI On ", valid_date, " stats was, confirmed: ",confirmed, "deaths: ", deaths, " and recovered: ", recovered)
            total_confirmed = total_confirmed + confirmed  
            total_deaths = total_deaths + deaths  
            total_recovered = total_recovered + recovered
            total_active = total_confirmed - (total_recovered + total_deaths)
    
            print("FINAL COUNT on" ,valid_date, "total confirmed:", total_confirmed, " total deaths:", total_deaths, " and total recovered:", total_recovered)
            #add_data_for_state_india('Delhi', valid_date, total_confirmed, delta_confirmed, total_deaths, delta_deaths, total_recovered, delta_recovered, total_active, delta_active)
            
    counter =0
# Out:
# IN DELHI On  03-14-2020  stats was, confirmed:  7 deaths:  1  and recovered:  1
# FINAL COUNT on 03-14-2020 total confirmed: 7  total deaths: 1  and total recovered: 1
# IN DELHI On  03-15-2020  stats was, confirmed:  0 deaths:  0  and recovered:  1
# FINAL COUNT on 03-15-2020 total confirmed: 7  total deaths: 1  and total recovered: 2
# IN DELHI On  03-16-2020  stats was, confirmed:  0 deaths:  0  and recovered:  0
# IN DELHI On  05-30-2020  stats was, confirmed:  1163 deaths:  18  and recovered:  229
# FINAL COUNT on 05-30-2020 total confirmed: 18549  total deaths: 416  and total recovered: 8075
# IN DELHI On  05-31-2020  stats was, confirmed:  1295 deaths:  57  and recovered:  403
# FINAL COUNT on 05-31-2020 total confirmed: 19844  total deaths: 473  and total recovered: 8478
# IN DELHI On  06-01-2020  stats was, confirmed:  990 deaths:  50  and recovered:  268
# FINAL COUNT on 06-01-2020 total confirmed: 20834  total deaths: 523  and total recovered: 8746
# IN DELHI On  06-02-2020  stats was, confirmed:  1298 deaths:  33  and recovered:  497
# FINAL COUNT on 06-02-2020 total confirmed: 22132  total deaths: 556  and total recovered: 9243
# IN DELHI On  06-03-2020  stats was, confirmed:  1513 deaths:  59  and recovered:  299
# FINAL COUNT on 06-03-2020 total confirmed: 23645  total deaths: 615  and total recovered: 9542
# IN DELHI On  06-04-2020  stats was, confirmed:  1359 deaths:  44  and recovered:  356
# FINAL COUNT on 06-04-2020 total confirmed: 25004  total deaths: 659  and total recovered: 9898
# IN DELHI On  06-05-2020  stats was, confirmed:  1330 deaths:  49  and recovered:  417
# FINAL COUNT on 06-05-2020 total confirmed: 26334  total deaths: 708  and total recovered: 10315
# IN DELHI On  06-06-2020  stats was, confirmed:  1320 deaths:  53  and recovered:  349
# FINAL COUNT on 06-06-2020 total confirmed: 27654  total deaths: 761  and total recovered: 10664

# %%
for key, value in STATE_CODES.items():
    print(key,value)
# Out:
# AP Andhra Pradesh
# AR Arunachal Pradesh
# AS Assam
# BR Bihar
# CT Chhattisgarh
# GA Goa
# GJ Gujarat
# HR Haryana
# HP Himachal Pradesh
# JH Jharkhand
# KA Karnataka
# KL Kerala
# MP Madhya Pradesh
# MH Maharashtra
# MN Manipur
# ML Meghalaya
# MZ Mizoram
# NL Nagaland
# OR Odisha
# PB Punjab
# RJ Rajasthan
# SK Sikkim
# TN Tamil Nadu
# TG Telangana
# TR Tripura
# UT Uttarakhand
# UP Uttar Pradesh
# WB West Bengal
# AN Andaman and Nicobar Islands
# CH Chandigarh
# DN Dadra and Nagar Haveli
# DD Daman and Diu
# DL Delhi
# JK Jammu and Kashmir
# LA Ladakh
# LD Lakshadweep
# PY Puducherry

# %%
def add_data_for_state_india(state, valid_date, total_confirmed, delta_confirmed, total_deaths, delta_deaths, total_recovered, delta_recovered, total_active, delta_active):
    if india_collection.find({'name': state}).count() >0:
        date_obj = {
            "date": str(valid_date),
            "confirmed": {"count": total_confirmed, "delta": delta_confirmed },
            "deaths": {"count": total_deaths, "delta": delta_deaths},
            "recovered": {"count": total_recovered, "delta": delta_recovered},
            "active": {"count":total_active, "delta": delta_active},
        }
        india_collection.update({'name': state}, {'$push': {'timeSeries': date_obj}}) 
    else:
        date_obj = [{
        "date": str(valid_date),
        "confirmed": {"count": total_confirmed, "delta": delta_confirmed },
        "deaths": {"count": total_deaths, "delta": delta_deaths},
        "recovered": {"count": total_recovered, "delta": delta_recovered},
        "active": {"count":total_active, "delta": delta_active},
        }]
        datax =  {
            "name": state,
            "coordinates":
            {
                "lat": '0',
                "long": '0'
            },
            "firstIncidentDate": "TBD",
            "timeSeries":date_obj,
            "lastUpdatedAt": "04-25-2020",
            "province": "NA"

        }
        x = india_collection.insert_one(datax)
